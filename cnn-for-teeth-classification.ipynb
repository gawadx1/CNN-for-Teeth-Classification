# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns
from pathlib import Path
import pandas as pd

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Configuration
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32
EPOCHS = 20
LEARNING_RATE = 0.001

# Define paths
BASE_DIR = '/kaggle/input/teeth-dataset-for-classification/Teeth_Dataset'
TRAIN_DIR = os.path.join(BASE_DIR, 'Training')
VAL_DIR = os.path.join(BASE_DIR, 'Validation')
TEST_DIR = os.path.join(BASE_DIR, 'Testing')

# Class names
CLASS_NAMES = ['CaS', 'CoS', 'Gum', 'MC', 'OC', 'OLP', 'OT']
NUM_CLASSES = len(CLASS_NAMES)

# 1. PREPROCESSING
print("=== PREPROCESSING ===")

# Create data generators with augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode='nearest'
)

# Validation and test data should only be rescaled
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Create data generators
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    shuffle=True
)

validation_generator = val_test_datagen.flow_from_directory(
    VAL_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    shuffle=False
)

test_generator = val_test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    shuffle=False
)

# 2. VISUALIZATION
print("\n=== VISUALIZATION ===")

# Function to count images in each class
def count_images_per_class(directory):
    class_counts = {}
    for class_name in CLASS_NAMES:
        class_path = os.path.join(directory, class_name)
        if os.path.exists(class_path):
            count = len([f for f in os.listdir(class_path) 
                        if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
            class_counts[class_name] = count
    return class_counts

# Count images in training, validation, and test sets
train_counts = count_images_per_class(TRAIN_DIR)
val_counts = count_images_per_class(VAL_DIR)
test_counts = count_images_per_class(TEST_DIR)

# Create visualization for class distribution
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Training set distribution
axes[0].bar(train_counts.keys(), train_counts.values(), color='skyblue')
axes[0].set_title('Training Set Distribution')
axes[0].set_xlabel('Class')
axes[0].set_ylabel('Number of Images')
axes[0].tick_params(axis='x', rotation=45)

# Validation set distribution
axes[1].bar(val_counts.keys(), val_counts.values(), color='lightgreen')
axes[1].set_title('Validation Set Distribution')
axes[1].set_xlabel('Class')
axes[1].set_ylabel('Number of Images')
axes[1].tick_params(axis='x', rotation=45)

# Test set distribution
axes[2].bar(test_counts.keys(), test_counts.values(), color='lightcoral')
axes[2].set_title('Test Set Distribution')
axes[2].set_xlabel('Class')
axes[2].set_ylabel('Number of Images')
axes[2].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('class_distribution.png')
plt.show()

# Display total counts
print("\nDataset Summary:")
print(f"Total training images: {sum(train_counts.values())}")
print(f"Total validation images: {sum(val_counts.values())}")
print(f"Total test images: {sum(test_counts.values())}")

# Visualize images before and after augmentation
def plot_augmentation_comparison():
    # Get a batch of images
    sample_batch, labels = next(train_generator)
    
    # Create generator without augmentation for comparison
    no_aug_gen = ImageDataGenerator(rescale=1./255)
    no_aug_generator = no_aug_gen.flow_from_directory(
        TRAIN_DIR,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        classes=CLASS_NAMES,
        shuffle=True
    )
    
    original_batch, _ = next(no_aug_generator)
    
    # Plot comparison
    fig, axes = plt.subplots(4, 4, figsize=(12, 12))
    fig.suptitle('Original vs Augmented Images', fontsize=16)
    
    for i in range(4):
        # Original images
        axes[i, 0].imshow(original_batch[i])
        axes[i, 0].set_title('Original')
        axes[i, 0].axis('off')
        
        # Augmented versions
        for j in range(1, 4):
            # Generate new augmented image
            aug_batch, _ = next(train_generator)
            axes[i, j].imshow(aug_batch[0])
            axes[i, j].set_title(f'Augmented {j}')
            axes[i, j].axis('off')
    
    plt.tight_layout()
    plt.savefig('augmentation_comparison.png')
    plt.show()

plot_augmentation_comparison()

# 3. MODEL ARCHITECTURE AND TRAINING
print("\n=== MODEL ARCHITECTURE ===")

# Build custom CNN model from scratch
def create_teeth_classification_model():
    model = keras.Sequential([
        # Input layer
        layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        
        # First convolutional block
        layers.Conv2D(32, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        # Second convolutional block
        layers.Conv2D(64, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(64, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        # Third convolutional block
        layers.Conv2D(128, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(128, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        # Fourth convolutional block
        layers.Conv2D(256, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(256, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        # Flatten and dense layers
        layers.GlobalAveragePooling2D(),
        layers.Dense(512),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.5),
        
        layers.Dense(256),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.5),
        
        # Output layer
        layers.Dense(NUM_CLASSES, activation='softmax')
    ])
    
    return model

# Create and compile model
model = create_teeth_classification_model()

# Compile model
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy', keras.metrics.Precision(), keras.metrics.Recall()]
)

# Display model summary
model.summary()

# Define callbacks
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        min_lr=1e-7,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        'best_teeth_classification_model.h5',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

# Train the model
print("\n=== TRAINING MODEL ===")
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=validation_generator,
    callbacks=callbacks,
    verbose=1
)

# Plot training history
def plot_training_history(history):
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))
    
    # Accuracy
    axes[0, 0].plot(history.history['accuracy'], label='Training Accuracy')
    axes[0, 0].plot(history.history['val_accuracy'], label='Validation Accuracy')
    axes[0, 0].set_title('Model Accuracy')
    axes[0, 0].set_xlabel('Epoch')
    axes[0, 0].set_ylabel('Accuracy')
    axes[0, 0].legend()
    axes[0, 0].grid(True)
    
    # Loss
    axes[0, 1].plot(history.history['loss'], label='Training Loss')
    axes[0, 1].plot(history.history['val_loss'], label='Validation Loss')
    axes[0, 1].set_title('Model Loss')
    axes[0, 1].set_xlabel('Epoch')
    axes[0, 1].set_ylabel('Loss')
    axes[0, 1].legend()
    axes[0, 1].grid(True)
    
    # Precision
    axes[1, 0].plot(history.history['precision'], label='Training Precision')
    axes[1, 0].plot(history.history['val_precision'], label='Validation Precision')
    axes[1, 0].set_title('Model Precision')
    axes[1, 0].set_xlabel('Epoch')
    axes[1, 0].set_ylabel('Precision')
    axes[1, 0].legend()
    axes[1, 0].grid(True)
    
    # Recall
    axes[1, 1].plot(history.history['recall'], label='Training Recall')
    axes[1, 1].plot(history.history['val_recall'], label='Validation Recall')
    axes[1, 1].set_title('Model Recall')
    axes[1, 1].set_xlabel('Epoch')
    axes[1, 1].set_ylabel('Recall')
    axes[1, 1].legend()
    axes[1, 1].grid(True)
    
    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

plot_training_history(history)

# Evaluate model on test set
print("\n=== EVALUATING MODEL ===")
test_loss, test_accuracy, test_precision, test_recall = model.evaluate(test_generator, verbose=1)

print(f"\nTest Results:")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall: {test_recall:.4f}")
print(f"Test Loss: {test_loss:.4f}")

# Generate predictions for confusion matrix
test_generator.reset()
predictions = model.predict(test_generator, verbose=1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes

# Create confusion matrix
from sklearn.metrics import confusion_matrix, classification_report

cm = confusion_matrix(true_classes, predicted_classes)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=CLASS_NAMES, 
            yticklabels=CLASS_NAMES)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.savefig('confusion_matrix.png')
plt.show()

# Generate classification report
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, 
                          target_names=CLASS_NAMES, 
                          digits=4))

# Save model and results
model.save('final_teeth_classification_model.h5')

# Create a summary report
with open('model_summary.txt', 'w') as f:
    f.write("Teeth Classification Model Summary\n")
    f.write("="*50 + "\n\n")
    f.write(f"Model Architecture: Custom CNN\n")
    f.write(f"Input Shape: ({IMG_HEIGHT}, {IMG_WIDTH}, 3)\n")
    f.write(f"Number of Classes: {NUM_CLASSES}\n")
    f.write(f"Classes: {', '.join(CLASS_NAMES)}\n\n")
    f.write("Training Configuration:\n")
    f.write(f"- Batch Size: {BATCH_SIZE}\n")
    f.write(f"- Learning Rate: {LEARNING_RATE}\n")
    f.write(f"- Epochs Trained: {len(history.history['accuracy'])}\n\n")
    f.write("Performance Metrics:\n")
    f.write(f"- Test Accuracy: {test_accuracy:.4f}\n")
    f.write(f"- Test Precision: {test_precision:.4f}\n")
    f.write(f"- Test Recall: {test_recall:.4f}\n")
    f.write(f"- Test Loss: {test_loss:.4f}\n")

print("\nProject completed successfully!")
print("Files saved:")
print("- best_teeth_classification_model.h5")
print("- final_teeth_classification_model.h5")
print("- class_distribution.png")
print("- augmentation_comparison.png")
print("- training_history.png")
print("- confusion_matrix.png")
print("- model_summary.txt")
# Out:
# 2025-07-02 10:38:25.773006: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751452705.797579     670 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751452705.805149     670 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# === PREPROCESSING ===
# Found 3087 images belonging to 7 classes.
# Found 1028 images belonging to 7 classes.
# Found 1028 images belonging to 7 classes.
#
# === VISUALIZATION ===
# Dataset Summary:
# Total training images: 3087
# Total validation images: 1028
# Total test images: 1028
# Found 3087 images belonging to 7 classes.
# === MODEL ARCHITECTURE ===
# I0000 00:00:1751452719.220982     670 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1751452719.221690     670 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 224, 224, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 224, 224, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 224, 224, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 112, 112, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 112, 112, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 112, 112, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 112, 112, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 56, 56, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 56, 56, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 56, 56, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 56, 56, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 28, 28, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 28, 28, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 28, 28, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 28, 28, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_7 (Activation)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_8 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 7)                   │           1,799 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,434,503 (5.47 MB)
#  Trainable params: 1,431,111 (5.46 MB)
#  Non-trainable params: 3,392 (13.25 KB)
# === TRAINING MODEL ===
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751452731.596016     737 service.cc:148] XLA service 0x783c8400abb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751452731.596052     737 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1751452731.596057     737 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1751452732.568932     737 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1751452748.659656     737 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.1865 - loss: 2.3683 - precision: 0.2230 - recall: 0.0549
# Epoch 1: val_accuracy improved from -inf to 0.14494, saving model to best_teeth_classification_model.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 83s 574ms/step - accuracy: 0.1868 - loss: 2.3670 - precision: 0.2234 - recall: 0.0550 - val_accuracy: 0.1449 - val_loss: 3.0802 - val_precision: 0.1449 - val_recall: 0.1449 - learning_rate: 0.0010
# Epoch 2/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.2489 - loss: 2.0058 - precision: 0.3566 - recall: 0.0860
# Epoch 2: val_accuracy did not improve from 0.14494
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 423ms/step - accuracy: 0.2490 - loss: 2.0054 - precision: 0.3569 - recall: 0.0860 - val_accuracy: 0.1449 - val_loss: 4.5900 - val_precision: 0.1449 - val_recall: 0.1449 - learning_rate: 0.0010
# Epoch 3/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.2963 - loss: 1.8742 - precision: 0.4299 - recall: 0.0941
# Epoch 3: val_accuracy improved from 0.14494 to 0.17704, saving model to best_teeth_classification_model.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 416ms/step - accuracy: 0.2963 - loss: 1.8738 - precision: 0.4302 - recall: 0.0942 - val_accuracy: 0.1770 - val_loss: 3.6177 - val_precision: 0.1868 - val_recall: 0.1654 - learning_rate: 0.0010
# Epoch 4/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.3328 - loss: 1.7114 - precision: 0.5038 - recall: 0.1223
# Epoch 4: val_accuracy improved from 0.17704 to 0.18774, saving model to best_teeth_classification_model.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 415ms/step - accuracy: 0.3327 - loss: 1.7116 - precision: 0.5037 - recall: 0.1223 - val_accuracy: 0.1877 - val_loss: 2.6578 - val_precision: 0.2076 - val_recall: 0.1060 - learning_rate: 0.0010
# Epoch 5/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.3361 - loss: 1.7062 - precision: 0.5469 - recall: 0.1222
# Epoch 5: val_accuracy did not improve from 0.18774
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 412ms/step - accuracy: 0.3363 - loss: 1.7058 - precision: 0.5471 - recall: 0.1223 - val_accuracy: 0.1800 - val_loss: 2.4294 - val_precision: 0.1816 - val_recall: 0.1479 - learning_rate: 0.0010
# Epoch 6/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.3945 - loss: 1.5845 - precision: 0.5682 - recall: 0.1536
# Epoch 6: val_accuracy improved from 0.18774 to 0.30642, saving model to best_teeth_classification_model.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 419ms/step - accuracy: 0.3944 - loss: 1.5847 - precision: 0.5683 - recall: 0.1535 - val_accuracy: 0.3064 - val_loss: 1.7748 - val_precision: 0.3810 - val_recall: 0.1868 - learning_rate: 0.0010
# Epoch 7/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.4012 - loss: 1.5367 - precision: 0.6005 - recall: 0.1765
# Epoch 7: val_accuracy improved from 0.30642 to 0.38619, saving model to best_teeth_classification_model.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 415ms/step - accuracy: 0.4013 - loss: 1.5366 - precision: 0.6005 - recall: 0.1766 - val_accuracy: 0.3862 - val_loss: 1.5488 - val_precision: 0.5588 - val_recall: 0.1479 - learning_rate: 0.0010
# Epoch 8/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.4139 - loss: 1.4652 - precision: 0.6164 - recall: 0.1993
# Epoch 8: val_accuracy did not improve from 0.38619
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 418ms/step - accuracy: 0.4141 - loss: 1.4650 - precision: 0.6165 - recall: 0.1994 - val_accuracy: 0.3735 - val_loss: 1.6563 - val_precision: 0.4855 - val_recall: 0.1955 - learning_rate: 0.0010
# Epoch 9/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.4591 - loss: 1.4022 - precision: 0.6003 - recall: 0.2269
# Epoch 9: val_accuracy did not improve from 0.38619
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 418ms/step - accuracy: 0.4592 - loss: 1.4021 - precision: 0.6006 - recall: 0.2270 - val_accuracy: 0.3434 - val_loss: 1.8557 - val_precision: 0.5157 - val_recall: 0.2072 - learning_rate: 0.0010
# Epoch 10/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.4797 - loss: 1.3987 - precision: 0.6348 - recall: 0.2470
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 10: val_accuracy did not improve from 0.38619
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 410ms/step - accuracy: 0.4797 - loss: 1.3983 - precision: 0.6348 - recall: 0.2471 - val_accuracy: 0.2772 - val_loss: 1.8962 - val_precision: 0.3804 - val_recall: 0.1809 - learning_rate: 0.0010
# Epoch 11/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.5233 - loss: 1.2233 - precision: 0.7132 - recall: 0.2999
# Epoch 11: val_accuracy improved from 0.38619 to 0.40856, saving model to best_teeth_classification_model.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 410ms/step - accuracy: 0.5234 - loss: 1.2232 - precision: 0.7131 - recall: 0.3001 - val_accuracy: 0.4086 - val_loss: 1.5099 - val_precision: 0.5114 - val_recall: 0.3064 - learning_rate: 5.0000e-04
# Epoch 12/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.5372 - loss: 1.2051 - precision: 0.6865 - recall: 0.3404
# Epoch 12: val_accuracy did not improve from 0.40856
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 409ms/step - accuracy: 0.5372 - loss: 1.2051 - precision: 0.6864 - recall: 0.3404 - val_accuracy: 0.2665 - val_loss: 2.1473 - val_precision: 0.3423 - val_recall: 0.1732 - learning_rate: 5.0000e-04
# Epoch 13/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.5437 - loss: 1.1761 - precision: 0.6818 - recall: 0.3516
# Epoch 13: val_accuracy improved from 0.40856 to 0.48735, saving model to best_teeth_classification_model.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 413ms/step - accuracy: 0.5438 - loss: 1.1760 - precision: 0.6818 - recall: 0.3517 - val_accuracy: 0.4874 - val_loss: 1.3227 - val_precision: 0.5952 - val_recall: 0.3375 - learning_rate: 5.0000e-04
# Epoch 14/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.5570 - loss: 1.1408 - precision: 0.6821 - recall: 0.3758
# Epoch 14: val_accuracy did not improve from 0.48735
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 412ms/step - accuracy: 0.5571 - loss: 1.1407 - precision: 0.6822 - recall: 0.3758 - val_accuracy: 0.4047 - val_loss: 1.5971 - val_precision: 0.5233 - val_recall: 0.3171 - learning_rate: 5.0000e-04
# Epoch 15/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.5847 - loss: 1.1076 - precision: 0.7132 - recall: 0.4143
# Epoch 15: val_accuracy did not improve from 0.48735
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 417ms/step - accuracy: 0.5846 - loss: 1.1077 - precision: 0.7131 - recall: 0.4142 - val_accuracy: 0.4319 - val_loss: 1.7368 - val_precision: 0.4960 - val_recall: 0.3619 - learning_rate: 5.0000e-04
# Epoch 16/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.5883 - loss: 1.0826 - precision: 0.7256 - recall: 0.4217
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 16: val_accuracy did not improve from 0.48735
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 415ms/step - accuracy: 0.5883 - loss: 1.0826 - precision: 0.7255 - recall: 0.4216 - val_accuracy: 0.3599 - val_loss: 1.9953 - val_precision: 0.4128 - val_recall: 0.3016 - learning_rate: 5.0000e-04
# Epoch 17/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.6144 - loss: 1.0073 - precision: 0.7218 - recall: 0.4496
# Epoch 17: val_accuracy improved from 0.48735 to 0.58560, saving model to best_teeth_classification_model.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 417ms/step - accuracy: 0.6145 - loss: 1.0073 - precision: 0.7219 - recall: 0.4498 - val_accuracy: 0.5856 - val_loss: 1.1341 - val_precision: 0.7158 - val_recall: 0.3920 - learning_rate: 2.5000e-04
# Epoch 18/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.6413 - loss: 0.9561 - precision: 0.7646 - recall: 0.4900
# Epoch 18: val_accuracy did not improve from 0.58560
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 412ms/step - accuracy: 0.6412 - loss: 0.9561 - precision: 0.7644 - recall: 0.4900 - val_accuracy: 0.5710 - val_loss: 1.1066 - val_precision: 0.6692 - val_recall: 0.4329 - learning_rate: 2.5000e-04
# Epoch 19/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.6407 - loss: 0.9457 - precision: 0.7519 - recall: 0.4862
# Epoch 19: val_accuracy improved from 0.58560 to 0.67510, saving model to best_teeth_classification_model.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 418ms/step - accuracy: 0.6409 - loss: 0.9455 - precision: 0.7520 - recall: 0.4864 - val_accuracy: 0.6751 - val_loss: 0.8701 - val_precision: 0.7932 - val_recall: 0.5671 - learning_rate: 2.5000e-04
# Epoch 20/20
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.6386 - loss: 0.9568 - precision: 0.7446 - recall: 0.4849
# Epoch 20: val_accuracy did not improve from 0.67510
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 40s 416ms/step - accuracy: 0.6387 - loss: 0.9566 - precision: 0.7447 - recall: 0.4851 - val_accuracy: 0.6119 - val_loss: 1.0497 - val_precision: 0.7174 - val_recall: 0.4446 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 19.
# === EVALUATING MODEL ===
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - accuracy: 0.7910 - loss: 0.6194 - precision: 0.8646 - recall: 0.6769
#
# Test Results:
# Test Accuracy: 0.6887
# Test Precision: 0.7765
# Test Recall: 0.5778
# Test Loss: 0.8364
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#          CaS     0.8301    0.7937    0.8115       160
#          CoS     0.7838    0.9732    0.8683       149
#          Gum     0.7672    0.7417    0.7542       120
#           MC     0.5263    0.7778    0.6278       180
#           OC     0.4870    0.6944    0.5725       108
#          OLP     0.8539    0.4222    0.5651       180
#           OT     0.8615    0.4275    0.5714       131
#
#     accuracy                         0.6887      1028
#    macro avg     0.7300    0.6901    0.6815      1028
# weighted avg     0.7350    0.6887    0.6820      1028
#
#
# Project completed successfully!
# Files saved:
# - best_teeth_classification_model.h5
# - final_teeth_classification_model.h5
# - class_distribution.png
# - augmentation_comparison.png
# - training_history.png
# - confusion_matrix.png
# - model_summary.txt

# %%
print('the end')
# Out:
# the end
